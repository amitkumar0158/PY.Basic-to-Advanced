# %%
 # Playing With Numbers
# int

# Float 

# complex

x= 1
     
y = 1.9

z = 3+2j

print(type(x))

print(type(y))

print(type(z))

#convert from int to float
#---------------------------
a = float(x)

#convert from float to int
#---------------------------
b = int(y)

#convert from int to comple
#---------------------------

c = complex(x)

print(a)
print(b)
print(c)


# mathematical operations
""" The different types of mathematical operations you can perform are:

(+)Addition
(-)Subtraction
(*)Multiplication 
(/)Division
(%)Modulus
(**)Exponentiation
(//)Floor division 
"""
a = 10
b = 20

print ( " Addition of two numbers is ",a+b)

print ( " Substraction of two numbers is ",a-b)

print ( " Multiplication of two numbers is ",a*b)

print ( " Division  of two numbers is ",a/b)

print ( " Modulous  of two numbers is ",a%b)

print ( " Exponential of two numbers is ",a**b)


print ( " Floor division of two numbers is ",a//b)
